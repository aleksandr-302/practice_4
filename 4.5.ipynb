# %%
x=0
height=int(input('количество строк: '))
while x<height:
  print('#',end=' ')
  c=0
  while c != x:
    print(' ',end=' ')
    c=c+1
  print('#')
  x=x+1
# Out:
# количество строк: 5
# # #
# #   #
# #     #
# #       #
# #         #
