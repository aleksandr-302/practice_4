# %%
v=int(input("Введите скорость транспортного средства в км/ч "))
t=int(input("Введите время движения "))
print('Час     Пройденное расстояние')
print('-----------------------------')
S=0
for i in range(1,t+1):
  S=v*i
  print(i,'     ',S)
# Out:
# Введите скорость транспортного средства в км/ч 30
# Введите время движения 4
# Час     Пройденное расстояние
# -----------------------------
# 1       30
# 2       60
# 3       90
# 4       120
