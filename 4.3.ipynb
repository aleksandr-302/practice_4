# %%
print("Вычисление факториала числа")
x=int(input('введите неотрицательное число '))
while x<0:
  x=int(input('введите неотрицательное число '))
fact=1
for i in range(1,x+1):
  fact=fact*i
print(x,"!=",fact)
# Out:
# Вычисление факториала числа
# введите неотрицательное число 7
# 7 != 5040
