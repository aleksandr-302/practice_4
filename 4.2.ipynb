# %%
print("Введите ряд положительных чисел:")
print("!Введите отрицательное число для конца числового ряда!")
x=0
place=0
sum=0
while x>=0:
  place=place+1
  print("Введите",place,"число")
  x=int(input())
  if x>0:
    sum=sum+x
print("Сумма положительных чисел=",sum)
# Out:
# Введите ряд положительных чисел:
# !Введите отрицательное число для конца числового ряда!
# Введите 1 число
# 2
# Введите 2 число
# 5
# Введите 3 число
# 3
# Введите 4 число
# -100
# Сумма положительных чисел= 10
